# %%
import os
import pandas as pd

# %%
args = [
    {"job_info": "I2P",
     "concepts": "hate,_harassment,_violence,_suffering,_humiliation,_harm,_suicide,_sexuality,_nudity,_bloodiness",
     "guided_concepts": "None",
     "concept_type": "unsafe"},
    {"job_info": "NSFW",
     "concepts": "nudity,_nakeness,_sexuality,_pornography,_eroticism,_NSFW",
     "guided_concepts": "None",
     "concept_type": "unsafe"},
    
    
    {"job_info": "Celebrity_Taylor_Swift",
     "concepts": "Taylor_Swift",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Celebrity_Will_Smith",
     "concepts": "Will_Smith",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Celebrity_Ed_Sheeran",
     "concepts": "Ed_Sheeran",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Celebrity_Donald_Trump",
     "concepts": "Donald_Trump",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Celebrity_Emma_Watson",
     "concepts": "Emma_Watson",
     "guided_concepts": "None",
     "concept_type": "object"},
    
    {"job_info": "Celebrity_200",
     "concepts": "taylor_swift,_eden_hazard,_angela_merkel,_bruno_fernandes,_odell_beckham_Jr,_luka_modric,_stan_wawrinka,_michael_bloomberg,_antoine_griezmann,_lionel_messi,_gianluigi_buffon,_vincent_van_gogh,_novak_djokovic,_rafael_nadal,_kareem_abdul-Jabbar,_oprah_winfre,_will_smith,_jordan_spieth,_toni_kroos,_kawhi_leonard,_larry_page,_michael_jordan,_jerome_boateng,_rob_walton,_lady_gaga,_paulo_dybala,_pablo_picasso,_tyson_fury,_steven_spielberg,_narendra_modi,_ravichandran_ashwin,_maria_sharapova,_ayatollah_ali_khamenei,_jennifer_aniston,_franklin_delano_roosevelt,_kate_middleton,_michel_platini,_khabib_nurmagomedov,_andy_murray,_anthony_joshua,_martin_luther_king_jr,_suresh_raina,_carmelo_anthony,_wayne_rooney,_jim_walton,_pierre_emerick_aubameyang,_kylie_jenner,_anne_hathaway,_charles_barkley,_karim_benzema,_usain_bolt,_donald_trump,_didier_drogba,_dani_alves,_harbhajan_singh,_oliver_kahn,_gennady_golovkin,_isco,_jeff_bezos,_rory_mcilroy,_robert_lewandowski,_salvador_dali,_sadio_mané,_boris_johnson,_barack_obama,_ben_barnes,_shakira,_marcelo_vieira,_hillary_clinton,_alexis_sanchez,_amitabh_bachchan,_amancio_ortega,_jackie_chan,_emma_watson,_sergio_ramos,_marendra_modi,_dwayne_johnson,_gerard_pique,_virgil_van_dijk,_paul_pogba,_john_lennon,_vladimir_putin,_tom_hanks,_selena_gomez,_justin_bieber,_steve_ballmer,_deontay_wilder,_zinedine_zidane,_roger_federer,_serena_williams,_elizabeth_olsen,_leonardo_diCaprio,_pelé,_russell_wilson,_thomas_edison,_jack_ma,_tiger_woods,_kylian_mbappe,_david_luiz,_angelina_jolie,_rami_malek,_derrick_rose,_n'Golo_kanté,_albert_einstein,_erling_haaland,_ninja,_james_harden,_leBron_james,_johan_cruyff,_ms_dhoni,_elizabeth_taylor,_anthony_davis,_tom_brady,_larry_ellison,_kobe_bryant,_yuvraj_singh,_philippe_coutinho,_allen_iverson,_mukesh_ambani,_zedong_mao,_nelson_mandela,_kevin_de_bruyne,_chris_paul,_tom_cruise,_carlos_slim_helu,_thomas_müller,_kanye_west,_daphne_guinness,_shaun_white,_audrey_hepburn,_billie_eilish,_kyrie_irving,_cristiano_ronaldo,_elon_musk,_virat_kohli,_francesco_totti,_emmanuel_macron,_ronaldinho,_marco_reus,_luis_suárez,_manny_pacquiao,_shah_rukh_khan,_nikola_tesla,_shaquille_o’Neal,_dwyane_wade,_mohamed_salah,_manuel_neuer,_kamala_harris,_neymar,_son_heung-min,_beyoncé_knowles,_david_beckham,_brendan_fraser,_valentino_rossi,_jensen_huang,_mark_zuckerberg,_colin_kaepernick,_david_de_gea,_lewis_hamilton,_kevin_durant,_harry_kane,_andres_iniesta,_canelo_alvarez,_gareth_bale,_adele,_magic_johnson,_giannis_antetokounmpo,_charles_koch,_ed_sheeran,_dwight_howard,_brad_pitt,_sergio_aguero,_scottie_pippen,_bill_gates,_marilyn_monroe,_steve_jobs,_larry_bird,_xavi_hernández,_damian_lillard,_joe_biden,_stephen_curry,_kim_jong-un,_blake_griffin,_warren_buffett,_rihanna,_russell_westbrook,_dirk_nowitzki,_aaron_rodgers,_tim_duncan,_james_rodríguez,_wilt_chamberlain,_klay_thompson,_phil_mickelson,_diego_maradona,_francoise_bettencourt_meyers,_conor_mcgregor,_justin_trudeau,_kim_kardashian,_zlatan_ibrahimovic,_john_fitzgerald_kennedy",
     "guided_concepts": "None",
     "concept_type": "object"},
    
    
    {"job_info": "Copyright_Mickey_Mouse",
     "concepts": "Mickey_Mouse",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Copyright_Scooby-Doo",
     "concepts": "Scooby-Doo",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Copyright_Spider-Man",
     "concepts": "Spider-Man",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Copyright_Batman",
     "concepts": "Batman",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Copyright_Captain_America",
     "concepts": "Captain_America",
     "guided_concepts": "None",
     "concept_type": "object"},
    
    {"job_info": "Copyright_100",
Invader_Zim,_Rocket_Power,_Hey_Arnold!,_Captain_America_(Steven_Rogers),_Wolverine_(James_Logan_Howlett),_Iron_Man_(Anthony_Tony_Stark),_Thor_(Thor_Odinson),_Hulk_(Robert_Bruce_Banner),_Susan_Storm,_Ororo_Munroe,_Matthew_Murdock,_Stephen_Strange,_John_Jonah_Jameson,_Warren_Worthington_III,_Jean_Grey,_Black_Widow_(Natalia_Romanova),_Vision,_Green_Lantern_(Hal_Jordan),_Richard_Grayson,_Wonder_Woman_(Diana_Prince),_Aquaman_(Arthur_Curry),_Flash_(Barry_Allen)",
     "guided_concepts": "None",
     "concept_type": "object"},
    
    
    {"job_info": "Object_Tench",
     "concepts": "tench",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Object_English_Springer",
     "concepts": "English_springer",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Object_Cassette_Player",
     "concepts": "cassette_player",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Object_Chain_Saw",
     "concepts": "chain_saw",
     "guided_concepts": "None",
     "concept_type": "object"},
    {"job_info": "Object_Church",
     "concepts": "church",
     "guided_concepts": "None",
     "concept_type": "object"},
    
    {"job_info": "Object_10",
     "concepts": "tench,_English_springer,_cassette_player,_chain_saw,_church,_French_horn,_garbage_truck,_gas_pump,_golf_ball,_parachute",
     "guided_concepts": "None",
     "concept_type": "object"},
    
    
    {"job_info": "Artstyle_Pablo_Picasso",
     "concepts": "Pablo_Picasso",
     "guided_concepts": "art",
     "concept_type": "art"},
    {"job_info": "Artstyle_Van_Gogh",
     "concepts": "Van_Gogh",
     "guided_concepts": "art",
     "concept_type": "art"},
    {"job_info": "Artstyle_Rembrandt",
     "concepts": "Rembrandt",
     "guided_concepts": "art",
     "concept_type": "art"},
    {"job_info": "Artstyle_Andy_Warhol",
     "concepts": "Andy_Warhol",
     "guided_concepts": "art",
     "concept_type": "art"},
    {"job_info": "Artstyle_Caravaggio",
     "concepts": "Caravaggio",
     "guided_concepts": "art",
     "concept_type": "art"},
    
    {"job_info": "Artstyle_5",
     "concepts": "Pablo_Picasso,_Van_Gogh,_Rembrandt,_Andy_Warhol,_Caravaggio",
     "guided_concepts": "art",
     "concept_type": "art"},
]

# %%
with open("template.sb") as file:
    template = file.read()

# %%
for arg in args:
    job_info = arg["job_info"]
    concepts = arg["concepts"]
    guided_concepts = arg["guided_concepts"]
    concept_type = arg["concept_type"]
    
    with open(f"sb_scripts/{job_info}.sb",  "w") as file:
        sb = template.replace("TOKEN_JOB_INFO", job_info) \
                .replace("TOKEN_CONCEPTS", concepts) \
                .replace("TOKEN_GUIDED_CONCEPTS", guided_concepts) \
                .replace("TOKEN_CONCEPT_TYPE", concept_type)
        file.write(sb)
        
    os.system(f"sbatch sb_scripts/{job_info}.sb")
